# %%
import pandas as pd
import numpy as np
pd.set_option('max_columns',200)

# %%
business = pd.read_csv('data/yelp_academic_dataset_business.csv')

business.head()
# Out:
#                address  attributes attributes_AcceptsInsurance  \
# 0    1314 44 Avenue NE         NaN                         NaN
# 1                  NaN         NaN                         NaN
# 2  1335 rue Beaubien E         NaN                         NaN
# 3      211 W Monroe St         NaN                         NaN
# 4  2005 Alyth Place SE         NaN                         NaN
#
#   attributes_AgesAllowed attributes_Alcohol  \
# 0                    NaN                NaN
# 1                    NaN               none
# 2                    NaN      beer_and_wine
# 3                    NaN                NaN
# 4                    NaN                NaN
#
#                                  attributes_Ambience attributes_BYOB  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2  {'romantic': False, 'intimate': False, 'classy...             NaN
# ...

# %%
LVdf = business[business['city'] == "Las Vegas"]

# %%
review = pd.read_csv('data/yelp_academic_dataset_review.csv')review.head()
# Out:
#               business_id  cool        date  funny               review_id  \
# 0  iCQpiavjjPzJ5_3gPD5Ebg     0  2011-02-25    0.0  x7mDIiDB3jEiPGPHOmDzyw
# 1  pomGBqfbxcqPv14c3XH-ZQ     0  2012-11-13    0.0  dDl8zu1vWPdKGihJrwQbpw
# 2  jtQARsP6P-LbkyjbO1qNGg     1  2014-10-23    1.0  LZp4UX5zK3e-c5ZGSeo3kA
# 3  elqbBhBfElMNSrjFqW3now     0  2011-02-25    0.0  Er4NBWCmCD4nM8_p1GRdow
# 4  Ums3gaP2qM3W1XcA5r6SsQ     0  2014-09-05    0.0  jsDu6QEJHbwP2Blom1PLCA
#
#    stars                                               text  useful  \
# 0    2.0  The pizza was okay. Not the best I've had. I p...     0.0
# 1    5.0  I love this place! My fiance And I go here atl...     0.0
# 2    1.0  Terrible. Dry corn bread. Rib tips were all fa...     3.0
# 3    2.0  Back in 2005-2007 this place was my FAVORITE t...     2.0
# 4    5.0  Delicious healthy food. The steak is amazing. ...     0.0
#
#                   user_id
# 0  msQe1u7Z_XuqjGoqhB0J5g
# 1  msQe1u7Z_XuqjGoqhB0J5g
# ...

# %%
LVdf = pd.merge(LVdf, review, on='business_id', how='inner')

# %%
LVdf.shape
# Out:
# (1825333, 69)

# %%
business.shape
# Out:
# (188593, 61)

# %%
LVdf.columns
# Out:
# Index(['address', 'attributes', 'attributes_AcceptsInsurance',
#        'attributes_AgesAllowed', 'attributes_Alcohol', 'attributes_Ambience',
#        'attributes_BYOB', 'attributes_BYOBCorkage', 'attributes_BestNights',
#        'attributes_BikeParking', 'attributes_BusinessAcceptsBitcoin',
#        'attributes_BusinessAcceptsCreditCards', 'attributes_BusinessParking',
#        'attributes_ByAppointmentOnly', 'attributes_Caters',
#        'attributes_CoatCheck', 'attributes_Corkage',
#        'attributes_DietaryRestrictions', 'attributes_DogsAllowed',
#        'attributes_DriveThru', 'attributes_GoodForDancing',
#        'attributes_GoodForKids', 'attributes_GoodForMeal',
#        'attributes_HairSpecializesIn', 'attributes_HappyHour',
#        'attributes_HasTV', 'attributes_Music', 'attributes_NoiseLevel',
#        'attributes_Open24Hours', 'attributes_OutdoorSeating',
#        'attributes_RestaurantsAttire', 'attributes_RestaurantsCounterService',
# ...

# %%
LVdf.shape
# Out:
# (1825333, 69)

# %%
business[business['city'] == "Las Vegas"].shape
# Out:
# (28865, 61)

# %%
del(business)

# %%
del(review)

# %%
LVdf.to_pickle("./LVdf.pkl")  #all businesses

# %%
#  LVdf = pd.read_pickle("./LVdf.pkl")
#  LVdf_sample = pd.read_pickle("./LVdf_sample.pkl")

# %%
LVdf[LVdf['categories'].isna()]
# Out:
# Empty DataFrame
# ...

# %%
LVdf['categories'] = LVdf['categories'].fillna("None")

# %%
LVdf = LVdf[LVdf['categories'].str.contains('Restaurant')]

# %%
LVdf.head()
# Out:
#                                   address  attributes  \
# 8   3940 Martin Luther King Blvd, Ste 101         NaN
# 9   3940 Martin Luther King Blvd, Ste 101         NaN
# 10  3940 Martin Luther King Blvd, Ste 101         NaN
# 31                    2255 N Rampart Blvd         NaN
# 32                    2255 N Rampart Blvd         NaN
#
#    attributes_AcceptsInsurance attributes_AgesAllowed attributes_Alcohol  \
# 8                          NaN                    NaN                NaN
# 9                          NaN                    NaN                NaN
# 10                         NaN                    NaN                NaN
# 31                         NaN                    NaN               none
# 32                         NaN                    NaN               none
#
#                                   attributes_Ambience attributes_BYOB  \
# 8                                                 NaN             NaN
# ...

# %%
LVdf.business_id.unique().size
# Out:
# 6153

# %%
LVdf.to_pickle("./LVdf_restaurants.pkl")

# %%
(LVdf.sample(100000)).to_pickle("./LVdf_sample.pkl")

# %%
LVdf.shape
# Out:
# (1053142, 69)

# %%
LVdf.describe()
# Out:
#        attributes  attributes_RestaurantsPriceRange2  hours       is_open  \
# count         0.0                       1.048665e+06    0.0  1.053142e+06
# mean          NaN                       1.995507e+00    NaN  8.427069e-01
# std           NaN                       7.266730e-01    NaN  3.640771e-01
# min           NaN                       1.000000e+00    NaN  0.000000e+00
# 25%           NaN                       2.000000e+00    NaN  1.000000e+00
# 50%           NaN                       2.000000e+00    NaN  1.000000e+00
# 75%           NaN                       2.000000e+00    NaN  1.000000e+00
# max           NaN                       4.000000e+00    NaN  1.000000e+00
#
#            latitude     longitude  review_count       stars_x          cool  \
# count  1.053142e+06  1.053142e+06  1.053142e+06  1.053142e+06  1.053142e+06
# mean   3.612123e+01 -1.151941e+02  1.032981e+03  3.770389e+00  6.772686e-01
# ...

# %%
df = LVdf[['address','business_id','categories','name','review_count','review_id','user_id','stars_y','text','useful']].copy()
           
           
#            'attributes_GoodForKids','attributes_RestaurantsGoodForGroups','attributes_GoodForMeal',\
#            'attributes_RestaurantsPriceRange2','attributes_DietaryRestrictions',\
#            'attributes_HappyHour','attributes_HasTV','attributes_Music','attributes_NoiseLevel',\
#            'attributes_GoodForDancing','attributes_DriveThru','attributes_Ambience','attributes_Alcohol',\
#            'attributes_Open24Hours','attributes_OutdoorSeating','attributes_RestaurantsAttire',\
#            'attributes_RestaurantsReservations','attributes_RestaurantsTableService','attributes_RestaurantsTakeOut',\
#            'review_count','stars_x','cool','date','funny','review_id','user_id','stars_y','text','useful')]

# %%
df
# Out:
#                                        address             business_id  \
# 8        3940 Martin Luther King Blvd, Ste 101  vJIuDBdu01vCA8y1fwR1OQ
# 9        3940 Martin Luther King Blvd, Ste 101  vJIuDBdu01vCA8y1fwR1OQ
# 10       3940 Martin Luther King Blvd, Ste 101  vJIuDBdu01vCA8y1fwR1OQ
# 31                         2255 N Rampart Blvd  kgffcoxT6BQp-gJ-UQ7Czw
# 32                         2255 N Rampart Blvd  kgffcoxT6BQp-gJ-UQ7Czw
# 33                         2255 N Rampart Blvd  kgffcoxT6BQp-gJ-UQ7Czw
# 34                         2255 N Rampart Blvd  kgffcoxT6BQp-gJ-UQ7Czw
# 35                         2255 N Rampart Blvd  kgffcoxT6BQp-gJ-UQ7Czw
# 36                         2255 N Rampart Blvd  kgffcoxT6BQp-gJ-UQ7Czw
# 37                         2255 N Rampart Blvd  kgffcoxT6BQp-gJ-UQ7Czw
# 38                         2255 N Rampart Blvd  kgffcoxT6BQp-gJ-UQ7Czw
# 39                         2255 N Rampart Blvd  kgffcoxT6BQp-gJ-UQ7Czw
# ...
